# %% [markdown]
# # Feature Engineering – Credit Default Dataset
#
# This notebook prepares a cleaned and feature-rich version of the **UCI Credit Default dataset** for modeling.
#
# **Goals:**
# - Clean and preprocess the raw data.
# - Engineer new features based on domain knowledge and EDA findings.
# - Save a processed dataset (`credit_processed.csv`) for modeling.

# %% [markdown]
# ## 1. Load Data

# %%
import sys
sys.path.append("../src")
import pandas as pd
import numpy as np
from data_loader import load_from_file, load_from_ucimlrepo

DATA_SOURCE = "local" #or api
LOCAL_FILE_PATH = "../data/credit.xls"

if DATA_SOURCE == "local":
    df = load_from_file(LOCAL_FILE_PATH)
elif DATA_SOURCE == "api":
    df = load_from_ucimlrepo()
else: 
    print("Wrong DATA SOURCE")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (30000, 25)
#    Unnamed: 0_level_0_ID  X1_LIMIT_BAL  X2_SEX  X3_EDUCATION  X4_MARRIAGE  \
# 0                      1         20000       2             2            1
# 1                      2        120000       2             2            2
# 2                      3         90000       2             2            2
# 3                      4         50000       2             2            1
# 4                      5         50000       1             2            1
#
#    X5_AGE  X6_PAY_0  X7_PAY_2  X8_PAY_3  X9_PAY_4  ...  X15_BILL_AMT4  \
# 0      24         2         2        -1        -1  ...              0
# 1      26        -1         2         0         0  ...           3272
# 2      34         0         0         0         0  ...          14331
# 3      37         0         0         0         0  ...          28314
# 4      57        -1         0        -1         0  ...          20940
#
#    X16_BILL_AMT5  X17_BILL_AMT6  X18_PAY_AMT1  X19_PAY_AMT2  X20_PAY_AMT3  \
# 0              0              0             0           689             0
# 1           3455           3261             0          1000          1000
# 2          14948          15549          1518          1500          1000
# 3          28959          29547          2000          2019          1200
# 4          19146          19131          2000         36681         10000
#
#    X21_PAY_AMT4  X22_PAY_AMT5  X23_PAY_AMT6  Y_default payment next month
# 0             0             0             0                             1
# 1          1000             0          2000                             1
# 2          1000          1000          5000                             0
# 3          1100          1069          1000                             0
# 4          9000           689           679                             0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 2. Data Cleaning

# %%
# Drop ID column (not predictive)
df = df.drop(columns=["Unnamed: 0_level_0_ID"], errors="ignore")
print(df["X3_EDUCATION"].value_counts())
print(df["X4_MARRIAGE"].value_counts())

# Replace out-of-range categories in EDUCATION and MARRIAGE
df["X3_EDUCATION"] = df["X3_EDUCATION"].replace({0:4, 5:4, 6:4})  # group as 'other'
df["X4_MARRIAGE"] = df["X4_MARRIAGE"].replace({0:3})              # group as 'other'

# Ensure target column is integer
df["Y_default payment next month"] = df["Y_default payment next month"].astype(int)

print(df["X3_EDUCATION"].value_counts())
print(df["X4_MARRIAGE"].value_counts())

# The dataset is relatively clean.
# Out:
# X3_EDUCATION
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: count, dtype: int64
# X4_MARRIAGE
# 2    15964
# 1    13659
# 3      377
# Name: count, dtype: int64
# X3_EDUCATION
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: count, dtype: int64
# X4_MARRIAGE
# 2    15964
# 1    13659
# 3      377
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Binning Features

# %%
# Bin AGE into categories
bins = [20,30,40,50,60,80]
labels = ["20-29","30-39","40-49","50-59","60+"]
df["AGE_BIN"] = pd.cut(df["X5_AGE"], bins=bins, labels=labels)

print("Shape: ",df.shape)
df[["X5_AGE","AGE_BIN"]].head(10)
# Out:
# Shape:  (30000, 25)
#    X5_AGE AGE_BIN
# 0      24   20-29
# 1      26   20-29
# 2      34   30-39
# 3      37   30-39
# 4      57   50-59
# 5      37   30-39
# 6      29   20-29
# 7      23   20-29
# 8      28   20-29
# 9      35   30-39

# %% [markdown]
# ## 4. Encoding Categorical Features

# %%
# One-hot encode categorical features (SEX, EDUCATION, MARRIAGE, AGE_BIN)
categorical_cols = ["X2_SEX","X3_EDUCATION","X4_MARRIAGE","AGE_BIN"]
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
print("Shape: ",df.shape)
df.head()
# Out:
# Shape:  (30000, 31)
#    X1_LIMIT_BAL  X5_AGE  X6_PAY_0  X7_PAY_2  X8_PAY_3  X9_PAY_4  X10_PAY_5  \
# 0         20000      24         2         2        -1        -1         -2
# 1        120000      26        -1         2         0         0          0
# 2         90000      34         0         0         0         0          0
# 3         50000      37         0         0         0         0          0
# 4         50000      57        -1         0        -1         0          0
#
#    X11_PAY_6  X12_BILL_AMT1  X13_BILL_AMT2  ...  X2_SEX_2  X3_EDUCATION_2  \
# 0         -2           3913           3102  ...      True            True
# 1          2           2682           1725  ...      True            True
# 2          0          29239          14027  ...      True            True
# 3          0          46990          48233  ...      True            True
# 4          0           8617           5670  ...     False            True
#
#    X3_EDUCATION_3  X3_EDUCATION_4  X4_MARRIAGE_2  X4_MARRIAGE_3  \
# 0           False           False          False          False
# 1           False           False           True          False
# 2           False           False           True          False
# 3           False           False          False          False
# 4           False           False          False          False
#
#    AGE_BIN_30-39  AGE_BIN_40-49  AGE_BIN_50-59  AGE_BIN_60+
# 0          False          False          False        False
# 1          False          False          False        False
# 2           True          False          False        False
# 3           True          False          False        False
# 4          False          False           True        False
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 5. Feature Engineering

# %%
# Utilization ratios (bill / limit)
for i in range(1,7):
    df[f"utilization{i}"] = df[f"X{11+i}_BILL_AMT{i}"] / df["X1_LIMIT_BAL"]

# Repayment ratios (payment / bill)
for i in range(1,7):
    df[f"repay_ratio{i}"] = df[f"X{17+i}_PAY_AMT{i}"] / df[f"X{11+i}_BILL_AMT{i}"].replace(0,np.nan)

# Payment delays: avg & max
pay_cols = ["X6_PAY_0","X7_PAY_2","X8_PAY_3","X9_PAY_4","X10_PAY_5","X11_PAY_6"]
df["avg_delay"] = df[pay_cols].mean(axis=1)
df["max_delay"] = df[pay_cols].max(axis=1)

# Aggregate bills and payments
bill_cols = [f"X{11+i}_BILL_AMT{i}" for i in range(1,7)]
pay_amt_cols = [f"X{17+i}_PAY_AMT{i}" for i in range(1,7)]
df["avg_bill"] = df[bill_cols].mean(axis=1)
df["avg_payment"] = df[pay_amt_cols].mean(axis=1)

df.head()
# Out:
#    X1_LIMIT_BAL  X5_AGE  X6_PAY_0  X7_PAY_2  X8_PAY_3  X9_PAY_4  X10_PAY_5  \
# 0         20000      24         2         2        -1        -1         -2
# 1        120000      26        -1         2         0         0          0
# 2         90000      34         0         0         0         0          0
# 3         50000      37         0         0         0         0          0
# 4         50000      57        -1         0        -1         0          0
#
#    X11_PAY_6  X12_BILL_AMT1  X13_BILL_AMT2  ...  repay_ratio1  repay_ratio2  \
# 0         -2           3913           3102  ...      0.000000      0.222115
# 1          2           2682           1725  ...      0.000000      0.579710
# 2          0          29239          14027  ...      0.051917      0.106937
# 3          0          46990          48233  ...      0.042562      0.041859
# 4          0           8617           5670  ...      0.232099      6.469312
#
#    repay_ratio3  repay_ratio4  repay_ratio5  repay_ratio6  avg_delay  \
# 0      0.000000           NaN           NaN           NaN  -0.333333
# 1      0.372856      0.305623      0.000000      0.613309   0.500000
# 2      0.073752      0.069779      0.066899      0.321564   0.000000
# 3      0.024345      0.038850      0.036914      0.033844   0.000000
# 4      0.279057      0.429799      0.035987      0.035492  -0.333333
#
#    max_delay      avg_bill  avg_payment
# 0          2   1284.000000   114.833333
# 1          2   2846.166667   833.333333
# 2          0  16942.166667  1836.333333
# 3          0  38555.666667  1398.000000
# 4          0  18223.166667  9841.500000
#
# [5 rows x 47 columns]

# %% [markdown]
# ## 6. Scaling & Transformations

# %%
# Apply log transform to skewed monetary features
def signed_log(x):
    return np.sign(x) * np.log1p(abs(x))

df[f"{col}_log"] = df[col].apply(signed_log)


df.head()
# Out:
#    X1_LIMIT_BAL  X5_AGE  X6_PAY_0  X7_PAY_2  X8_PAY_3  X9_PAY_4  X10_PAY_5  \
# 0         20000      24         2         2        -1        -1         -2
# 1        120000      26        -1         2         0         0          0
# 2         90000      34         0         0         0         0          0
# 3         50000      37         0         0         0         0          0
# 4         50000      57        -1         0        -1         0          0
#
#    X11_PAY_6  X12_BILL_AMT1  X13_BILL_AMT2  ...  X14_BILL_AMT3_log  \
# 0         -2           3913           3102  ...           6.536692
# 1          2           2682           1725  ...           7.894691
# 2          0          29239          14027  ...           9.514880
# 3          0          46990          48233  ...          10.805517
# 4          0           8617           5670  ...          10.486708
#
#    X15_BILL_AMT4_log  X16_BILL_AMT5_log  X17_BILL_AMT6_log  X18_PAY_AMT1_log  \
# 0           0.000000           0.000000           0.000000          0.000000
# 1           8.093462           8.147867           8.090096          0.000000
# 2           9.570250           9.612400           9.651816          7.325808
# 3          10.251147          10.273671          10.293771          7.601402
# 4           9.949464           9.859901           9.859118          7.601402
#
#    X19_PAY_AMT2_log  X20_PAY_AMT3_log  X21_PAY_AMT4_log  X22_PAY_AMT5_log  \
# 0          6.536692          0.000000          0.000000          0.000000
# 1          6.908755          6.908755          6.908755          0.000000
# 2          7.313887          6.908755          6.908755          6.908755
# 3          7.610853          7.090910          7.003974          6.975414
# 4         10.510041          9.210440          9.105091          6.536692
#
#    X23_PAY_AMT6_log
# 0          0.000000
# 1          7.601402
# 2          8.517393
# 3          6.908755
# 4          6.522093
#
# [5 rows x 60 columns]

# %% [markdown]
# ## 7. Save Processed Dataset

# %%
output_path = "../data/credit_processed.csv"
df.to_csv(output_path, index=False)
print(f"Processed dataset saved to {output_path}")
# Out:
# Processed dataset saved to ../data/credit_processed.csv

# %% [markdown]
# ## 8. Observations
#
# - Engineered new behavioral features (utilization ratios, repayment ratios, delays).
# - Aggregated across months to create summary variables (average bill, average payment).
# - Applied log transforms to normalize skewed monetary features.
# - Final dataset is ready for modeling.
